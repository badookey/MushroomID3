# %%
import pandas as pd
import torch
import numpy as np
from skimage import io, transform
from math import log
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from decimal import Decimal

# %% [markdown]
# # Decision Tree Classifier

# %%
class DecisionTreeNode:
    def __init__(self, parent):
        self.parent=parent
        self.children= dict()
    
    def add_child(self, child_key, child_value):
        self.children[child_key] = child_value
        
    def get_children(self):
        return self.children
    
    def get_parent(self):
        return self.parent
    
    def get_attribute(self):
        return self.attribute
    
    def set_attribute(self, attribute):
        self.attribute = attribute
        
    def set_label(self, label):
        self.label=label
    
    def get_label(self):
        return self.label
    
    def __str__(self, level=1):
        text=""
        if hasattr(self, 'label'):
            text += "leaf: label = {}".format(self.label)
        else:
            text += "split {}, descendants(".format(self.attribute)
            for value, child in self.children.items():
                text += "\n"+"   "*level+"branch = {}, child node:{}".format(value, child.__str__(level+1))
            
            text += ")"
        return text

# %%
def entropy(target_):
    h = 0
    for label_ in target_.unique():
        h += -((target_[target_==label_].size / target_.size)* log(target_[target_==label_].size / target_.size, 2))
    return h

def determine_split_attribute(data_, label_position_, attributes_):
    best_attribute_ = None
    best_gain_ = 0
    base_entropy_ = entropy(data_.iloc[:,label_position_])
    for attribute_ in attributes_:
        x_select_ = data_.loc[:,[attribute_, data_.columns[label_position_]]]
        information_gain_ = base_entropy_
        for value_ in x_select_.loc[:,attribute_].unique():
            #split_ = pd.concat([x_select_[x_select_==value_], target_], axis=1, join='inner')
            split_entropy_ = entropy(x_select_.iloc[:,label_position_])
            information_gain_ -= split_entropy_ * (x_select_.size / data_.size)
        
        if information_gain_ >= best_gain_:
            best_attribute_ = attribute_
            best_gain = information_gain_
            
    return best_attribute_

# %%
#param attributes_ should be a set of attributes
#param target_ should be a series (like y_train)
#param data_ should be a dataframe (like x_train)
def build_decision_tree(data_, attributes_, label_position_):
    node_ = DecisionTreeNode(None)
    if data_.iloc[:,label_position_].unique().size==1:
        node_.set_label(data_.iloc[0,label_position_])
        return node_
        
    if len(attributes_) == 0:
        node_.set_label(data_.iloc[:,label_position_].value_counts().head(1).last_valid_index())
        return node_
        
    else:
        split_attribute_ = determine_split_attribute(data_, label_position_, attributes_)
        print('splitting on: {}'.format(split_attribute_))
        node_.set_attribute(split_attribute_)
        split_select_ = data_.loc[:,split_attribute_]
        for split_value_ in split_select_.unique():
            child_data_ = data_[data_[split_attribute_] == split_value_]
            child_attributes_ = attributes_
            child_attributes_.remove(split_attribute_)
            #print('child_attributes: {}'.format(child_attributes_))
            node_.add_child(split_value_, build_decision_tree(child_data_,child_attributes_, label_position_))
            #print('currend subtree: {}'.format(node_))
            child_attributes_.add(split_attribute_)
            
    return node_

# %%
#data should be a dataframe (like x_train)
#root should be a a DecisionTreeNode (returned from build_decision_tree)
def make_prediction(root, data):
    predictions = dict()
    for i, point in data.iterrows():
        current_node_ = root
        not_predicted = True
        while not_predicted:
            if(hasattr(current_node_, 'label')):
                predictions[i]=current_node_.get_label()
                not_predicted = False
            else:
                split_value = point[current_node_.get_attribute()]
                try:
                    current_node_ = current_node_.get_children()[split_value]
                except KeyError:
                    current_node_ = list(current_node_.get_children().values())[0]
    result = pd.Series(predictions)
    return result

# %%
# TODO: model.fit() model.predict()
# requires df -> set of attributes

class DecisionTreeClassifier:
    def fit(self, data_, label_position_):
        self.tree=build_decision_tree(data_, extract_attribute_set(data_, label_position_), label_position_)
        
    def predict(self, data_):
        return make_prediction(self.tree, data_)
    
    def print_model(self):
        print(self.tree)

# %%
def extract_attribute_set(dataframe_, label_position_):
    indexes = [i for i in range(dataframe_.columns.size) if i != label_position_]
    x = dataframe_.iloc[:,indexes]
    return set(x.columns.values.tolist())

# %%
def load_data(path, header_included_):
    if header_included_:
        data = pd.read_csv(path)
    else:
        data = pd.read_csv(path, header=None)
        add_default = read_Bool("Do you want to add the default mushroom header? (True/False)")
        if add_default:
            assign_mushroom_header(data)
        
   # encoder = LabelEncoder()

    #benchmark speedup of encoding
    #for attr in shrooms:
        #data[attr] = encoder.fit_transform(data[attr].astype('str'))
        
    return data

def assign_mushroom_header(dataframe_):
    #Input column names from Mushroom Attributes.txt
    columns=['class','cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat']

    #Rename columns according to their real attributes
    dataframe_.set_axis(columns, axis='columns', inplace=True)
    
def split_data(dataframe_, test_size_):
    #y is our target class
    #y = dataframe_.iloc[:,label_position]
    #indexes = [i for i in range(dataframe_.columns.size) if i != label_position]
    #x is our attributes
    #x = dataframe_.iloc[:,indexes]
    
    #x_train_, x_test_, y_train_, y_test_ = train_test_split(x,y,test_size = test_size_)
    train_, test_ = train_test_split(dataframe_, test_size = test_size_)
    return train_, test_

# %%
def print_accuracy(real_values, predicted_values):
    stats= pd.crosstab(index = predicted_values, columns=real_values, margins=True, rownames= ['predicted'], colnames=['actual'])
    accuracy = np.sum(real_values == predicted_values) / predicted_values.size
    print(stats)
    print("The accuracy is: {}".format(accuracy))

# %%
# TODO: main for command line interface
def read_Bool(msg):
    text = input(msg)
    if text == "True":
        text = True
    elif text == "False":
        text = False
    else:
        return read_Bool(msg)
    return text
def read_float(msg):
    try:
        d = float(input(msg))
    except:
        print("invalid input, please try again")
        read_float(msg)
    if 0<d<1:
        return d
    print("the relative size has to be between 0.0 and 1.0")
    read_float(msg)
    
def read_int(msg):
    try:
        i = int(input(msg))
    except:
        print("invalid input, please try again")
        read_int(msg)
    return i
    
def main():
    path = input("enter the absolute path of the dataset: ")
    header_included = read_Bool("is the header included in the dataset?: (True/False)")
    data = load_data(path, header_included)
    split_size = read_float("enter the relative size of the test set: ")
    train, test = split_data(data, split_size)
    model = DecisionTreeClassifier()
    label_position = read_int("enter the position of the class label in the dataset: ")
    print("Training the model")
    model.fit(train, label_position)
    print('your model: \n\n')
    model.print_model()
    print("\n\nevaluating on test set:")
    predict = model.predict(test)
    print('\n\n')
    print_accuracy(test.iloc[:,label_position], predict)

# %%
main()
# Out:
# enter the absolute path of the dataset: Data/Mushrooms.txt
# is the header included in the dataset?: (True/False)True
# enter the relative size of the test set: 0.2
# enter the position of the class label in the dataset: 0
# Training the model
# splitting on: f
# splitting on: c
# splitting on: w.2
# splitting on: k.1
# splitting on: x
# splitting on: e.1
# splitting on: e.1
# splitting on: w
# splitting on: x
# splitting on: w.1
# splitting on: n
# splitting on: e.1
# splitting on: s.1
# splitting on: s
# splitting on: w.1
# splitting on: e.1
# splitting on: n
# splitting on: s.1
# splitting on: s
# splitting on: n
# splitting on: k
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: w
# splitting on: x
# splitting on: w.1
# splitting on: e.1
# splitting on: n
# splitting on: k
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: n
# splitting on: s.1
# splitting on: s
# splitting on: w.1
# splitting on: n
# splitting on: e.1
# splitting on: s.1
# splitting on: s
# splitting on: k
# splitting on: w
# splitting on: x
# splitting on: w.1
# splitting on: n
# splitting on: w.1
# splitting on: w.1
# splitting on: w.2
# splitting on: w
# splitting on: w.1
# splitting on: e.1
# splitting on: k.1
# splitting on: x
# splitting on: n
# splitting on: k
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: s.1
# splitting on: s
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: s.2
# splitting on: s.3
# splitting on: u
# splitting on: p.3
# splitting on: o
# splitting on: p.2
# splitting on: e
# splitting on: c
# splitting on: w.2
# your model:
#
#
# split f, descendants(
#    branch = f, child node:split c, descendants(
#       branch = c, child node:split w.2, descendants(
#          branch = w, child node:split k.1, descendants(
#             branch = h, child node:split x, descendants(
#                branch = f, child node:split e.1, descendants(
#                   branch = b, child node:leaf: label = p
#                   branch = ?, child node:leaf: label = e)
#                branch = x, child node:split e.1, descendants(
#                   branch = b, child node:leaf: label = p
#                   branch = ?, child node:leaf: label = e))
#             branch = k, child node:split w, descendants(
#                branch = w, child node:split x, descendants(
#                   branch = f, child node:split w.1, descendants(
#                      branch = w, child node:split n, descendants(
#                         branch = n, child node:split e.1, descendants(
#                            branch = e, child node:split s.1, descendants(
#                               branch = s, child node:split s, descendants(
#                                  branch = s, child node:leaf: label = p
#                                  branch = y, child node:leaf: label = p
#                                  branch = f, child node:leaf: label = e))
#                            branch = b, child node:leaf: label = e
#                            branch = r, child node:leaf: label = e)
#                         branch = y, child node:leaf: label = e
#                         branch = g, child node:leaf: label = e
#                         branch = w, child node:leaf: label = p
#                         branch = e, child node:leaf: label = e)
#                      branch = g, child node:leaf: label = e
#                      branch = p, child node:leaf: label = e)
#                   branch = x, child node:split w.1, descendants(
#                      branch = w, child node:split e.1, descendants(
#                         branch = e, child node:split n, descendants(
#                            branch = w, child node:leaf: label = p
#                            branch = n, child node:split s.1, descendants(
#                               branch = s, child node:split s, descendants(
#                                  branch = s, child node:leaf: label = p
#                                  branch = y, child node:leaf: label = p
#                                  branch = f, child node:leaf: label = e))
#                            branch = g, child node:leaf: label = e)
#                         branch = c, child node:leaf: label = e
#                         branch = b, child node:split n, descendants(
#                            branch = n, child node:leaf: label = e
#                            branch = p, child node:leaf: label = p
#                            branch = w, child node:leaf: label = p
#                            branch = g, child node:split k, descendants(
#                               branch = p, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = t, child node:leaf: label = e
#                                                          branch = e, child node:leaf: label = p)))))
#                                           branch = y, child node:leaf: label = e
#                                           branch = s, child node:leaf: label = p))
#                                     branch = s, child node:leaf: label = p
#                                     branch = y, child node:leaf: label = e))
#                               branch = n, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = y, child node:leaf: label = e
#                                           branch = s, child node:leaf: label = p
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = e, child node:leaf: label = p
#                                                          branch = t, child node:leaf: label = e)))))))
#                                     branch = s, child node:leaf: label = p
#                                     branch = y, child node:leaf: label = e))
#                               branch = u, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = y, child node:leaf: label = e
#                                     branch = s, child node:leaf: label = p
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = s, child node:leaf: label = p
#                                           branch = y, child node:leaf: label = e
#                                           branch = v, child node:leaf: label = p))))
#                               branch = g, child node:leaf: label = p
#                               branch = w, child node:leaf: label = e)
#                            branch = e, child node:leaf: label = e)
#                         branch = r, child node:leaf: label = e)
#                      branch = p, child node:leaf: label = e
#                      branch = g, child node:leaf: label = e)
#                   branch = b, child node:leaf: label = e
#                   branch = s, child node:leaf: label = e)
#                branch = p, child node:leaf: label = e
#                branch = g, child node:leaf: label = e)
#             branch = n, child node:split w, descendants(
#                branch = g, child node:leaf: label = e
#                branch = p, child node:leaf: label = e
#                branch = w, child node:split x, descendants(
#                   branch = b, child node:leaf: label = e
#                   branch = x, child node:split w.1, descendants(
#                      branch = w, child node:split e.1, descendants(
#                         branch = b, child node:split n, descendants(
#                            branch = g, child node:split k, descendants(
#                               branch = u, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = s, child node:leaf: label = p
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = e, child node:leaf: label = p
#                                                          branch = t, child node:leaf: label = e)))))
#                                           branch = y, child node:leaf: label = e
#                                           branch = s, child node:leaf: label = p))
#                                     branch = y, child node:leaf: label = e))
#                               branch = g, child node:leaf: label = p
#                               branch = n, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = y, child node:leaf: label = e
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:leaf: label = p
#                                           branch = y, child node:leaf: label = e
#                                           branch = s, child node:leaf: label = p))))
#                               branch = p, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = y, child node:leaf: label = e
#                                     branch = s, child node:leaf: label = p
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = e, child node:leaf: label = p
#                                                          branch = t, child node:leaf: label = e)))))
#                                           branch = y, child node:leaf: label = e
#                                           branch = s, child node:leaf: label = p))))
#                               branch = w, child node:leaf: label = e)
#                            branch = w, child node:leaf: label = p
#                            branch = n, child node:leaf: label = e
#                            branch = e, child node:leaf: label = e
#                            branch = p, child node:leaf: label = p)
#                         branch = e, child node:split n, descendants(
#                            branch = g, child node:leaf: label = e
#                            branch = n, child node:split s.1, descendants(
#                               branch = s, child node:split s, descendants(
#                                  branch = y, child node:leaf: label = p
#                                  branch = s, child node:leaf: label = p
#                                  branch = f, child node:leaf: label = e))
#                            branch = w, child node:leaf: label = p)
#                         branch = r, child node:leaf: label = e
#                         branch = c, child node:leaf: label = e)
#                      branch = p, child node:leaf: label = e
#                      branch = g, child node:leaf: label = e)
#                   branch = f, child node:split w.1, descendants(
#                      branch = w, child node:split n, descendants(
#                         branch = e, child node:leaf: label = e
#                         branch = n, child node:split e.1, descendants(
#                            branch = r, child node:leaf: label = e
#                            branch = e, child node:split s.1, descendants(
#                               branch = s, child node:split s, descendants(
#                                  branch = y, child node:leaf: label = p
#                                  branch = f, child node:leaf: label = e
#                                  branch = s, child node:leaf: label = p))
#                            branch = b, child node:leaf: label = e)
#                         branch = w, child node:leaf: label = p
#                         branch = y, child node:leaf: label = e
#                         branch = g, child node:leaf: label = e)
#                      branch = g, child node:leaf: label = e
#                      branch = p, child node:leaf: label = e)
#                   branch = s, child node:leaf: label = e))
#             branch = w, child node:split k, descendants(
#                branch = b, child node:leaf: label = p
#                branch = w, child node:split w, descendants(
#                   branch = c, child node:leaf: label = p
#                   branch = w, child node:split x, descendants(
#                      branch = f, child node:split w.1, descendants(
#                         branch = n, child node:leaf: label = p
#                         branch = w, child node:leaf: label = e
#                         branch = y, child node:leaf: label = p
#                         branch = e, child node:leaf: label = e)
#                      branch = k, child node:split n, descendants(
#                         branch = p, child node:leaf: label = e
#                         branch = e, child node:leaf: label = e
#                         branch = n, child node:split w.1, descendants(
#                            branch = w, child node:leaf: label = e
#                            branch = e, child node:leaf: label = e
#                            branch = n, child node:leaf: label = p
#                            branch = y, child node:leaf: label = p)
#                         branch = y, child node:leaf: label = p
#                         branch = b, child node:leaf: label = e)
#                      branch = x, child node:split w.1, descendants(
#                         branch = w, child node:leaf: label = e
#                         branch = n, child node:leaf: label = p
#                         branch = e, child node:leaf: label = e
#                         branch = y, child node:leaf: label = p)
#                      branch = b, child node:leaf: label = p)
#                   branch = e, child node:leaf: label = e
#                   branch = n, child node:leaf: label = e)
#                branch = e, child node:leaf: label = e
#                branch = y, child node:leaf: label = p)
#             branch = r, child node:leaf: label = p))
#       branch = w, child node:split w.2, descendants(
#          branch = w, child node:split w, descendants(
#             branch = w, child node:split w.1, descendants(
#                branch = w, child node:split e.1, descendants(
#                   branch = ?, child node:leaf: label = e
#                   branch = e, child node:leaf: label = e
#                   branch = b, child node:split k.1, descendants(
#                      branch = n, child node:split x, descendants(
#                         branch = x, child node:split n, descendants(
#                            branch = w, child node:split k, descendants(
#                               branch = g, child node:leaf: label = p
#                               branch = n, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = s, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = e, child node:leaf: label = p
#                                                          branch = t, child node:leaf: label = e)))))
#                                           branch = s, child node:leaf: label = p))
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = t, child node:leaf: label = e
#                                                          branch = e, child node:leaf: label = p)))))))))
#                               branch = p, child node:split s.1, descendants(
#                                  branch = s, child node:split s, descendants(
#                                     branch = f, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = s, child node:leaf: label = p
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = t, child node:leaf: label = e
#                                                          branch = e, child node:leaf: label = p)))))))
#                                     branch = s, child node:split s.2, descendants(
#                                        branch = s, child node:split s.3, descendants(
#                                           branch = v, child node:split u, descendants(
#                                              branch = d, child node:split p.3, descendants(
#                                                 branch = p, child node:split o, descendants(
#                                                    branch = o, child node:split p.2, descendants(
#                                                       branch = p, child node:split e, descendants(
#                                                          branch = e, child node:leaf: label = p
#                                                          branch = t, child node:leaf: label = e)))))))))
#                               branch = u, child node:leaf: label = p
#                               branch = w, child node:leaf: label = e)
#                            branch = y, child node:leaf: label = e
#                            branch = g, child node:leaf: label = p
#                            branch = p, child node:leaf: label = p)
#                         branch = f, child node:leaf: label = e)
#                      branch = u, child node:leaf: label = e
#                      branch = k, child node:leaf: label = p
#                      branch = w, child node:leaf: label = p))
#                branch = n, child node:leaf: label = e))
#          branch = y, child node:leaf: label = p))
#    branch = a, child node:split c, descendants(
#       branch = c, child node:split w.2, descendants(
#          branch = n, child node:leaf: label = e
#          branch = o, child node:leaf: label = e
#          branch = w, child node:leaf: label = p)))
#
#
# evaluating on test set:
# actual       e    p   All
# predicted
# e          841    2   843
# p            2  780   782
# All        843  782  1625
# The accuracy is: 0.9975384615384615
